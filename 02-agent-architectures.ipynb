# %% [markdown]
# # Multi-Agent Systems & Workflow Patterns
#
# **Day 1B — Google ADK | Local VS Code**
#
# You’ll build:
# - Multi-agent teams
# - Sequential, Parallel, Loop workflows
# - LLM as manager
#
# ---
# **No Kaggle. No extra installs. Just code.**

# %% [markdown]
# ### Load API Key

# %%
import os
from dotenv import load_dotenv

load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    raise ValueError("Add GOOGLE_API_KEY to .env in project root!")

os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "FALSE"

print("Gemini API key loaded!")
# Out:
# Gemini API key loaded!

# %% [markdown]
# ### Import ADK

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search

print("ADK ready!")
# Out:
# ADK ready!

# %% [markdown]
# ### Why Multi-Agent Systems?
#
# Single agent = Do-it-all (unreliable for complex tasks)
#
# Multi-agent = Team of specialists (easier to build/debug/powerful)

# %% [markdown]
# ### Research Agent

# %%
research_agent = Agent(
    name="ResearchAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %% [markdown]
# ### Summarizer Agent

# %%
summarizer_agent = Agent(
    name="SummarizerAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %% [markdown]
# ### Root Coordinator

# %%
root_agent = Agent(
    name="ResearchCoordinator",
    model="gemini-2.5-flash-lite",
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    tools=[
        AgentTool(research_agent),
        AgentTool(summarizer_agent)
    ],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %% [markdown]
# ### Create Runner & Run

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("When is the next prelims of UPSC 2026?")
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "F:\AI-Agents-ADK\agents\Lib\site-packages\google\adk\agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > When is the next prelims of UPSC 2026?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "F:\AI-Agents-ADK\agents\Lib\site-packages\google\adk\agents", which implies app name "agents".
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "F:\AI-Agents-ADK\agents\Lib\site-packages\google\adk\agents", which implies app name "agents".
# ResearchCoordinator > The UPSC Civil Services Preliminary Examination for 2026 is scheduled for May 24, 2026. The official notification is expected on January 14, 2026, with the application window open until February 3, 2026. The Mains examination will begin on August 21, 2026.

# %% [markdown]
# ## Sequential Workflows - The Assembly Line
#
# Use when: Order matters (e.g., Outline → Write → Edit)

# %% [markdown]
# #### Outline Agent

# %%
outline_agent = Agent(
    name="OutlineAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Based on the user's topic, create a detailed outline for a blog post.
    Include sections like Introduction, Main Points, and Conclusion.
    Output only the outline as a bulleted list.""",
    output_key="blog_outline",
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %% [markdown]
# #### Writer Agent

# %%
writer_agent = Agent(
    name="WriterAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Using this outline: {blog_outline}
Write a full blog post draft. Make it engaging and around 400-600 words.
Output only the blog post text.""",
    output_key="blog_draft",
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %% [markdown]
# #### Editor Agent

# %%
editor_agent = Agent(
    name="EditorAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Review this blog draft: {blog_draft}
Edit for clarity, grammar, flow, and engagement.
Output the final edited version.""",
    output_key="final_blog",
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %% [markdown]
# ### Sequential Root

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential root_agent created.")
# Out:
# ✅ Sequential root_agent created.

# %% [markdown]
# #### Run Sequential

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a blog post about the benefits of meditation for programmers")
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "F:\AI-Agents-ADK\agents\Lib\site-packages\google\adk\agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of meditation for programmers
# OutlineAgent > *   **Introduction**
#     *   Hook: The demanding nature of programming – long hours, complex problem-solving, constant learning.
#     *   Introduce meditation as a potential tool for programmers.
#     *   Briefly state the blog post's purpose: to explore the tangible benefits of meditation for those in the coding world.
#     *   Thesis statement: Meditation can significantly enhance a programmer's cognitive abilities, emotional resilience, and overall well-being, leading to improved performance and a more sustainable career.
#
# *   **Main Points**
#
#     *   **Enhanced Focus and Concentration**
#         *   The "flow state" in programming: deep concentration, immersion.
#         *   How meditation trains the brain to resist distractions (internal and external).
#         *   Specific meditation techniques beneficial for focus (e.g., breath awareness).
#         *   Real-world impact: fewer bugs, faster problem-solving, more efficient coding sessions.
#
#     *   **Improved Problem-Solving and Creativity**
#         *   The challenge of debugging and finding elegant solutions.
#         *   How a calmer mind can approach complex problems with clarity.
#         *   Meditation's role in reducing cognitive load and freeing up mental resources.
#         *   Cultivating a more open and innovative mindset for brainstorming and design.
#
#     *   **Stress Reduction and Emotional Regulation**
#         *   Common stressors for programmers: deadlines, bugs, demanding clients, imposter syndrome.
#         *   The physiological effects of stress and how they hinder performance.
#         *   Meditation as a tool to manage the stress response (e.g., lowering cortisol).
#         *   Developing emotional resilience to setbacks and constructive criticism.
#         *   Preventing burnout.
#
#     *   **Increased Self-Awareness and Mindfulness**
#         *   Understanding one's own thought patterns and biases.
#         *   How mindfulness can lead to better code reviews and collaboration.
#         *   Recognizing when you're stuck or feeling overwhelmed before it escalates.
#         *   Developing a healthier relationship with technology and screen time.
#
#     *   **Getting Started with Meditation (Practical Advice)**
#         *   Debunking myths: "I don't have time," "I can't clear my mind."
#         *   Simple, actionable steps for beginners.
#         *   Recommended duration (e.g., 5-10 minutes daily).
#         *   Types of meditation to explore (e.g., guided, unguided, walking meditation).
#         *   Resources: apps (Calm, Headspace, Insight Timer), online tutorials, local groups.
#         *   Consistency over perfection.
#
# *   **Conclusion**
#     *   Recap of the key benefits discussed.
#     *   Reiterate the thesis: meditation is a valuable, accessible tool for programmers to thrive.
#     *   Call to action: Encourage readers to try incorporating meditation into their routine, even for a short duration.
#     *   Final thought: Meditation isn't about escaping reality, but about engaging with it more effectively and with greater well-being.
# WriterAgent > In the fast-paced world of programming, where long hours, complex problem-solving, and constant learning are the norm, maintaining peak performance can feel like an uphill battle. We push our brains to their limits, often forgetting the importance of mental conditioning. But what if there was a tool that could not only enhance your cognitive abilities but also foster emotional resilience and overall well-being? Enter meditation. This post explores how incorporating meditation into your routine can significantly boost your effectiveness as a programmer, leading to improved performance and a more sustainable career.
#
# **Sharpen Your Focus, Enter the Flow**
#
# The "flow state" – that immersive zone of deep concentration where code seems to write itself – is the holy grail for many developers. Meditation is a powerful training ground for your brain, teaching it to resist the constant barrage of internal and external distractions. By practicing simple techniques like breath awareness, you train your mind to return to the present moment, a skill directly transferable to debugging complex issues or architecting intricate systems. This enhanced focus means fewer bugs, faster problem-solving, and ultimately, more productive coding sessions.
#
# **Unlock Better Problem-Solving and Creativity**
#
# Debugging can be a mental marathon. Finding elegant solutions often requires a clear, uncluttered mind. Meditation helps reduce cognitive load, freeing up mental resources that would otherwise be occupied by stress and rumination. A calmer mind approaches complex problems with greater clarity and less frustration, fostering an environment where innovative solutions can emerge. By quieting the mental noise, you cultivate a more open and receptive mindset, essential for brainstorming and creative design.
#
# **Navigate Stress, Build Resilience**
#
# Deadlines loom, bugs appear out of nowhere, clients demand the impossible, and imposter syndrome whispers doubts. The stressors in a programmer's life are plentiful and can take a significant toll. Chronic stress negatively impacts cognitive function and can lead to burnout. Meditation acts as a powerful antidote, helping to manage the body's stress response and lower cortisol levels. This practice builds emotional resilience, allowing you to handle setbacks and constructive criticism with greater equanimity, protecting you from burnout.
#
# **Cultivate Self-Awareness and Mindfulness**
#
# Understanding your own thought patterns, biases, and tendencies is crucial for effective collaboration. Mindfulness, a key component of meditation, enhances this self-awareness. It can lead to more insightful code reviews, better team communication, and the ability to recognize when you're stuck or overwhelmed before it escalates. Furthermore, it helps develop a healthier relationship with the technology that dominates our lives, allowing for more intentional screen time.
#
# **Getting Started: It's Easier Than You Think**
#
# The biggest hurdles for many are the myths: "I don't have time" or "I can't clear my mind." The truth is, you don't need hours. Just 5-10 minutes a day can make a difference. Start with guided meditations using apps like Calm, Headspace, or Insight Timer. Focus on your breath, notice sensations, and gently guide your attention back when your mind wanders. Consistency, not perfection, is key.
#
# Meditation is not about escaping reality; it's about engaging with it more effectively. By investing a small amount of time in this practice, programmers can unlock significant improvements in their cognitive abilities, emotional well-being, and overall career sustainability. Give it a try – your future self (and your codebase) will thank you.
# EditorAgent > In the fast-paced world of programming, where long hours, complex problem-solving, and constant learning are the norm, maintaining peak performance can feel like an uphill battle. We often push our brains to their limits, forgetting the crucial importance of mental conditioning. But what if there was a tool that could not only enhance your cognitive abilities but also foster emotional resilience and overall well-being? Enter meditation. This post explores how incorporating meditation into your routine can significantly boost your effectiveness as a programmer, leading to improved performance and a more sustainable career.
#
# ### Sharpen Your Focus, Enter the Flow State
#
# The "flow state" – that immersive zone of deep concentration where code seems to write itself – is the holy grail for many developers. Meditation is a powerful training ground for your brain, teaching it to resist the constant barrage of internal and external distractions. By practicing simple techniques like breath awareness, you train your mind to return to the present moment, a skill directly transferable to debugging complex issues or architecting intricate systems. This enhanced focus means fewer bugs, faster problem-solving, and ultimately, more productive coding sessions.
#
# ### Unlock Better Problem-Solving and Creativity
#
# Debugging can be a mental marathon, and finding elegant solutions often requires a clear, uncluttered mind. Meditation helps reduce cognitive load, freeing up mental resources that would otherwise be occupied by stress and rumination. A calmer mind approaches complex problems with greater clarity and less frustration, fostering an environment where innovative solutions can emerge. By quieting the mental noise, you cultivate a more open and receptive mindset, essential for brainstorming and creative design.
#
# ### Navigate Stress and Build Resilience
#
# Deadlines loom, unexpected bugs appear, clients demand the impossible, and imposter syndrome whispers doubts. The stressors in a programmer's life are plentiful and can take a significant toll. Chronic stress negatively impacts cognitive function and can lead to burnout. Meditation acts as a powerful antidote, helping to manage the body's stress response and lower cortisol levels. This practice builds emotional resilience, allowing you to handle setbacks and constructive criticism with greater equanimity, protecting you from burnout.
#
# ### Cultivate Self-Awareness and Mindfulness
#
# Understanding your own thought patterns, biases, and tendencies is crucial for effective collaboration. Mindfulness, a key component of meditation, significantly enhances this self-awareness. It can lead to more insightful code reviews, better team communication, and the ability to recognize when you're stuck or overwhelmed before it escalates. Furthermore, it helps develop a healthier relationship with the technology that dominates our lives, allowing for more intentional screen time.
#
# ### Getting Started: It's Easier Than You Think
#
# The biggest hurdles for many are common myths: "I don't have time" or "I can't clear my mind." The truth is, you don't need hours. Just 5-10 minutes a day can make a profound difference. Start with guided meditations using popular apps like Calm, Headspace, or Insight Timer. Focus on your breath, notice sensations, and gently guide your attention back when your mind wanders. Consistency, not perfection, is the key to reaping the benefits.
#
# Meditation isn't about escaping reality; it's about engaging with it more effectively. By investing a small amount of time in this practice, programmers can unlock significant improvements in their cognitive abilities, emotional well-being, and overall career sustainability. Give it a try – your future self (and your codebase) will thank you.

# %% [markdown]
# ## Parallel Workflows - The Research Team
#
# Use when: Independent tasks (e.g., Multi-topic research)

# %%
#### Parallel Agents

tech_researcher = Agent(
    name="TechResearcher",
    model="gemini-2.5-flash-lite",
    instruction="Research the latest in Tech. Use google_search. Output 3 key updates.",
    tools=[google_search],
    output_key="tech_report",
)

health_researcher = Agent(
    name="HealthResearcher",
    model="gemini-2.5-flash-lite",
    instruction="Research the latest in Health. Use google_search. Output 3 key updates.",
    tools=[google_search],
    output_key="health_report",
)

finance_researcher = Agent(
    name="FinanceResearcher",
    model="gemini-2.5-flash-lite",
    instruction="Research the latest in Finance. Use google_search. Output 3 key updates.",
    tools=[google_search],
    output_key="finance_report",
)

aggregator_agent = Agent(
    name="AggregatorAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Compile these reports into a single executive briefing:
Tech: {tech_report}
Health: {health_report}
Finance: {finance_report}
Format as sections with headings.""",
    output_key="exec_briefing",
)

print("✅ Parallel agents created.")
# Out:
# ✅ Parallel agents created.

# %% [markdown]
# ### Parallel Team

# %%
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel + Sequential created.")
# Out:
# ✅ Parallel + Sequential created.

# %% [markdown]
# ### Run Parallel

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Run the daily executive briefing on Tech, Health, and Finance")
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "F:\AI-Agents-ADK\agents\Lib\site-packages\google\adk\agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# FinanceResearcher > Here are three key updates in Finance for November 2025:
#
# *   **Federal Reserve's Cautious Easing Amid Economic Uncertainty:** The Federal Reserve has continued its rate cuts, influenced by weakening employment trends, despite ongoing inflation concerns. However, internal disagreements within the Fed are growing, with some officials advocating for faster cuts and others urging caution due to persistent inflation. The likelihood of a December rate cut is now uncertain, as Fed Chair Powell described the current policy-making environment as akin to "driving in fog," emphasizing a slower approach until clearer economic data emerges.
#
# *   **Stablecoin Regulation on the Horizon:** The Bank of England has launched a consultation on a proposed regulatory regime for sterling-denominated systemic stablecoins. This initiative aims to prepare for a future where digital currencies play a larger role in payments. The proposed rules would allow systemic stablecoin issuers to hold a significant portion of their backing assets in short-term UK government debt, with the remainder held in unremunerated accounts at the Bank of England. Non-systemic stablecoins would be regulated by the Financial Conduct Authority (FCA).
#
# *   **Revised Large Financial Institution Rating System:** The Federal Reserve Board has finalized revisions to its Large Financial Institution (LFI) rating system and the Insurance Supervisory Framework. These changes alter the criteria for a firm to be considered "well managed," with a new approach stating that a firm with at least two component ratings of "Broadly Meets Expectations" or "Conditionally Meets Expectations" and no more than one "Deficient-1" rating will be deemed "well managed."
# TechResearcher > Here's your executive briefing for today:
#
# **Technology:**
#
# *   **Apple's Satellite Features Expansion:** Apple is reportedly working on expanding satellite features for the iPhone, including offline maps and photo messaging capabilities. This suggests a continued focus on enhancing connectivity beyond traditional cellular networks.
# *   **AI in Technology:** Microsoft is building a frontier AI lab to achieve self-sufficiency in artificial intelligence development. Additionally, a new AI technique is being developed for sounding out audio deepfakes, and Microsoft has identified a security flaw in AI chatbots that could expose conversation topics.
# *   **Gaming and Hardware:** Xbox Cloud Gaming is now officially available in India, allowing users to play console and PC games on various devices. Sony has also introduced a new 240Hz PlayStation monitor designed for competitive gaming.
#
# **Health:**
#
# *   **Menopause Drug Safety:** The FDA has removed a long-standing warning from hormone-based menopause drugs, potentially impacting treatment options for many women.
# *   **AI in Healthcare:** AI tools are being developed to tackle sepsis, a leading cause of death in hospitals, with early successes in saving lives.
# *   **Public Health Alerts:** Several recalls and warnings have been issued, including Peloton bike recalls due to injury risks, Listeria outbreaks linked to prepared pasta meals, and a recall of certain Häagen-Dazs ice cream bars.
#
# **Finance:**
#
# *   **Market Performance:** The Indian Rupee has fallen 15 paise to 88.65 against the U.S. dollar in early trade. Meanwhile, stock markets are showing signs of climbing on firm global cues and optimism about an India-U.S. trade deal.
# *   **Corporate Earnings:** Bajaj Finserv reported an 8% rise in its Q2 net profit, reaching ₹2,244 crore.
# *   **Insurance Sector Growth:** Life insurers have seen a 12% rise in new business premium in October, partly attributed to GST relief. The retail health insurance segment also experienced a boost from pent-up demand during the same period.
# HealthResearcher > Here's your executive briefing for Tuesday, November 11, 2025, covering key updates in Health, Technology, and Finance.
#
# ### Health Updates:
#
# *   **Americas Lose Measles Elimination Status:** The Pan American Health Organization (PAHO) announced that the Region of the Americas has lost its verification as being free from endemic measles transmission. This decision follows a commission's review of the epidemiological situation, which concluded that endemic measles transmission has been reestablished in Canada, with significant cases also reported in Mexico and the United States. Active outbreaks are ongoing in several countries, primarily affecting under-vaccinated communities.
# *   **Flu Vaccine Effectiveness:** Early data from the UK Health Security Agency (UKHSA) indicates that the 2025/26 flu vaccine is providing strong protection, showing 70-75% effectiveness against hospital attendance in children aged 2-17 and 30-40% effectiveness in adults, despite an unusually early flu season driven by a new subclade of influenza A(H3N2).
# *   **Global Health Funding Pledges:** The Global Fund to Fight AIDS, Tuberculosis and Malaria welcomed the United Kingdom's pledge of GBP850 million for its Eighth Replenishment. This funding aims to save millions of lives, reduce new infections, and combat major infectious diseases globally.
#
# ### Technology Updates:
#
# *   **Major AI Cloud Deals and Infrastructure Investment:** Nebius Group has signed a five-year, $3 billion contract with Meta for AI cloud infrastructure. Concurrently, Microsoft announced a $10 billion investment in a Portuguese AI data hub, highlighting a significant race for AI infrastructure and data sovereignty in Europe.
# *   **New Pixel Drop Features:** Google has released its November 2025 Pixel drop, introducing features like a "Remix" option for photo editing in Messages, AI-powered notification summaries, and expanded availability of "Scam Detection" and "Call Notes" to more regions.
# *   **Flagship Smartphone Launches:** November 2025 is set to be a significant month for smartphone releases, with new models from iQOO, Realme, and OnePlus featuring advanced processors like the Snapdragon 8 Elite Gen 5 and high-refresh-rate displays.
#
# ### Finance Updates:
#
# *   **Global Economy Facing Headwinds:** The global economy is navigating a precarious period in November 2025, characterized by geopolitical tensions, policy fragmentation, and structural economic shifts. Despite strong performance in many equity markets, risks persist, including potential trade escalations between the US and China and cyber threats.
# *   **Housing Market Heat-Up:** Australia's housing market is showing signs of warming, with new lending rising significantly faster than anticipated in the September quarter. Investor lending, in particular, has seen a substantial increase, suggesting a potential easing of financial conditions.
# *   **Stock Market Outlook:** Bank of America's outlook for November 2025 is bullish, identifying technology, consumer discretionary, healthcare, industrials, and small-cap stocks as key sectors poised for strong performance. This optimism is fueled by easing inflation, cooling yields, and resilient consumer spending.
# AggregatorAgent > ## Executive Briefing: November 2025
#
# This briefing synthesizes key updates from the Technology, Health, and Finance sectors, providing a concise overview of recent developments and outlooks.
#
# ### Technology
#
# Recent advancements in technology highlight a significant push in artificial intelligence, expanded connectivity options, and new hardware for both consumers and gamers.
#
# *   **AI Dominance and Security:** The race for AI dominance continues with Microsoft establishing a frontier AI lab for self-sufficiency and investing $10 billion in a Portuguese AI data hub. Nebius Group has also secured a $3 billion, five-year contract with Meta for AI cloud infrastructure. Alongside these investments, new AI techniques are emerging for audio deepfake detection, and Microsoft has identified a critical security flaw in AI chatbots that could expose user conversation topics.
# *   **Connectivity and Consumer Tech:** Apple is reportedly expanding its iPhone satellite features to include offline maps and photo messaging, indicating a move towards enhanced off-grid connectivity. Google's November Pixel drop introduces AI-powered notification summaries, photo editing "Remix" options, and expanded availability of "Scam Detection" and "Call Notes." The smartphone market is also gearing up for significant launches in November 2025, with new models from iQOO, Realme, and OnePlus featuring advanced processors and high-refresh-rate displays.
# *   **Gaming and Hardware Expansion:** Xbox Cloud Gaming has officially launched in India, broadening access to console and PC games across various devices. Sony is catering to competitive gamers with a new 240Hz PlayStation monitor.
#
# ### Health
#
# The health sector is facing challenges with the resurgence of measles in the Americas and evolving vaccine effectiveness, while also seeing progress in AI-driven diagnostics and significant global health funding commitments.
#
# *   **Disease Outbreaks and Vaccine Efficacy:** The Region of the Americas has lost its measles elimination status due to reestablished endemic transmission in Canada, Mexico, and the United States. Concurrently, early data from the UK suggests strong protection from the 2025/26 flu vaccine, particularly in children, despite an early and aggressive flu season driven by a new influenza A(H3N2) subclade.
# *   **AI in Healthcare and Public Health Alerts:** AI tools are showing early success in combating sepsis, a leading cause of hospital mortality. On the consumer front, there have been several product recalls and warnings, including Peloton bikes due to injury risks, Listeria concerns with prepared pasta meals, and a recall of specific Häagen-Dazs ice cream bars.
# *   **Global Health Funding:** The Global Fund has received a significant pledge of GBP850 million from the United Kingdom for its Eighth Replenishment, aiming to combat AIDS, Tuberculosis, and Malaria globally.
#
# ### Finance
#
# The financial landscape in November 2025 is marked by cautious economic policy, evolving regulatory frameworks for digital assets, and a generally optimistic but risk-aware market outlook.
#
# *   **Monetary Policy and Economic Outlook:** The Federal Reserve is proceeding with rate cuts amid weakening employment trends but faces internal debate over the pace due to persistent inflation concerns. Fed Chair Powell has described the current environment as "driving in fog," suggesting a slower, data-dependent approach. The global economy is navigating headwinds from geopolitical tensions and policy fragmentation, though equity markets remain robust. Bank of America projects a bullish outlook for November 2025, favoring technology, consumer discretionary, healthcare, industrials, and small-cap stocks.
# *   **Financial Regulation and Digital Assets:** The Bank of England has initiated a consultation for a regulatory regime for sterling-denominated stablecoins, signaling preparation for increased digital currency usage. The Federal Reserve has also finalized revisions to its Large Financial Institution (LFI) rating system and Insurance Supervisory Framework, adjusting the criteria for defining a "well managed" firm.
# *   **Market Performance and Sector Trends:** The Indian Rupee has seen a slight depreciation against the U.S. dollar, while Indian stock markets are climbing on positive global cues and trade deal optimism. Bajaj Finserv reported an 8% rise in its Q2 net profit. The insurance sector is experiencing growth, with life insurers seeing a 12% increase in new business premium in October and the retail health insurance segment boosted by pent-up demand. Australia's housing market is also showing signs of warming, with increased new lending, particularly from investors.

# %% [markdown]
# ## Loop Workflows - The Refinement Cycle
#
# Use when: Iterative improvement (e.g., Writer + Critic loop)

# %% [markdown]
# ### Loop Agents & Run

# %%
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",
)

critic_agent = Agent(
    name="CriticAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",
)

def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}

refiner_agent = Agent(
    name="RefinerAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    
    output_key="current_story",
    tools=[FunctionTool(exit_loop)],
)

story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,
)

root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop agents created.")

runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a short story about a lighthouse keeper who discovers a mysterious, glowing map")
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "F:\AI-Agents-ADK\agents\Lib\site-packages\google\adk\agents", which implies app name "agents".
# ✅ Loop agents created.
#
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias, his beard perpetually flecked with salt spray, polished the great Fresnel lens. The kerosene lamp hummed its familiar tune, a melody against the gnawing Atlantic wind. Tonight, however, the rhythm was broken by a dull thud against the lighthouse base. He descended the spiral stairs, oil lamp casting dancing shadows.
#
# On the rocky shore, nestled amongst seaweed and barnacles, lay a rolled parchment, strangely untouched by the sea. Unfurling it, Elias gasped. It wasn't paper, but a material that shimmered, shifting with an internal, ethereal light. Etched upon its surface were lines and symbols he’d never seen, a celestial chart perhaps, or a map of some forgotten realm. As he traced a pulsing, blue current, a faint warmth spread through his fingertips. The map glowed brighter, its luminescence a silent invitation.
# CriticAgent > This is a strong start to a story, with excellent atmospheric detail and an intriguing hook.
#
# Here are a few suggestions for improvement:
#
# 1.  **Develop Elias's reaction and internal state further:** While his gasp is noted, more of Elias's thoughts and feelings about this extraordinary discovery would deepen the reader's connection to him. What are his initial emotions beyond surprise? Fear, wonder, scientific curiosity? Showing his internal processing of such an impossible object would make him more relatable.
# 2.  **Hint at the map's potential purpose or origin:** The description of the map is evocative, but a subtle clue about *what* it might be for would increase the suspense. Is it a map to treasure, a guide to another dimension, or something else entirely? A small, ambiguous detail could greatly enhance the mystery.
# 3.  **Consider the immediate next step:** The story ends with the map glowing and issuing an "invitation." While this is a great cliffhanger, briefly showing Elias contemplating what to do next – or even him taking a tentative first action – would provide a more satisfying, albeit still open-ended, conclusion to this segment.
# RefinerAgent > Elias, his beard perpetually flecked with salt spray, polished the great Fresnel lens. The kerosene lamp hummed its familiar tune, a melody against the gnawing Atlantic wind. Tonight, however, the rhythm was broken by a dull thud against the lighthouse base. He descended the spiral stairs, oil lamp casting dancing shadows, a knot of apprehension tightening in his stomach. He wasn't prone to fear, but the sound was unnatural, too heavy for driftwood, too deliberate for debris.
#
# On the rocky shore, nestled amongst seaweed and barnacles, lay a rolled parchment, strangely untouched by the sea. Unfurling it, Elias gasped, a tremor running through his aged hands. It wasn't paper, but a material that shimmered, shifting with an internal, ethereal light, cool and smooth beneath his calloused fingertips. Etched upon its surface were lines and symbols he’d never seen, not constellations, nor any earthly cartography. It pulsed with faint lines of blue and gold, reminiscent of currents in the deep ocean, or perhaps Ley lines of a forgotten magic. As he traced a pulsing, blue current, a faint warmth spread through his fingertips, igniting a spark of pure wonder mixed with a primal, unsettling curiosity. What ancient sorcery or lost civilization could have crafted such an artifact? The map glowed brighter, its luminescence a silent invitation, not to a place, but to a *possibility*. Elias looked from the impossible object to the dark, churning sea, then back to the map. A choice, a dangerous, thrilling choice, lay before him. He carefully rolled the map, its light still pulsing, a secret to be unraveled in the quiet solitude of his lighthouse.
# CriticAgent > APPROVED
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
